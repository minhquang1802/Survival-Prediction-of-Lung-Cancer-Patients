# %%
import os
import glob
import torch
from torch.utils.tensorboard import SummaryWriter
from monai.transforms import (
    Compose, LoadImaged, Spacingd, Orientationd,
    ScaleIntensityRanged, CropForegroundd, RandCropByPosNegLabeld,
    RandFlipd, RandRotate90d, EnsureTyped, EnsureChannelFirstd, DivisiblePadd
)
from monai.data import DataLoader, CacheDataset, decollate_batch
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
import time
from datetime import datetime

# %%
# === Setup path ===
root_dir = "/mrhung_nguyen_minh_quang_108/workspace/train/nnUNet_raw/Dataset015_lungTumor"
images = sorted(glob.glob(os.path.join(root_dir, "imagesTr", "*.nii.gz")))
labels = sorted(glob.glob(os.path.join(root_dir, "labelsTr", "*.nii.gz")))

model_dir = "./saved_models"
log_dir = "./runs/UNet_lung"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

log_file = os.path.join(log_dir, "training_log.txt")
def log_to_file(message, file_path=log_file):
    with open(file_path, "a") as f:
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        f.write(f"[{timestamp}] {message}\n")

# === Resume from checkpoint if exists ===
checkpoint_path = os.path.join(model_dir, "last_checkpoint.pth")
start_epoch = 0
best_metric = -1
best_metric_epoch = -1

writer = SummaryWriter(log_dir=log_dir)
data_dicts = [{"image": img, "label": lbl} for img, lbl in zip(images, labels)]

# %%
val_frac = 0.2
val_split = int(len(data_dicts) * (1 - val_frac))
train_files = data_dicts[:val_split]
val_files = data_dicts[val_split:]

# %%
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(2.0, 2.0, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=400, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image", allow_smaller=True),
    DivisiblePadd(keys=["image", "label"], k=16),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=(96, 96, 96),
        pos=1, neg=1, num_samples=2, image_key="image", image_threshold=0
    ),
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    RandRotate90d(keys=["image", "label"], prob=0.5, max_k=3),
    EnsureTyped(keys=["image", "label"]),
])

# %%
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(2.0, 2.0, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=400, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image", allow_smaller=True),
    DivisiblePadd(keys=["image", "label"], k=16),
    EnsureTyped(keys=["image", "label"]),
])

# %%
train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=2)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2, persistent_workers=True, pin_memory=True)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=2, persistent_workers=True, pin_memory=True)
# Out:
# Loading dataset: 100%|██████████| 92/92 [08:27<00:00,  5.52s/it]
# Loading dataset: 100%|██████████| 23/23 [01:46<00:00,  4.65s/it]

# %%
if __name__ == "__main__":
    start_time = time.time()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = UNet(
        spatial_dims=3,
        in_channels=1,
        out_channels=1,
        channels=(16, 32, 64, 128, 256),
        strides=(2, 2, 2, 2),
        num_res_units=2,
    ).to(device)

    loss_function = DiceLoss(sigmoid=True)
    optimizer = torch.optim.Adam(model.parameters(), 1e-4)
    dice_metric = DiceMetric(include_background=False, reduction="mean")
    scaler = torch.cuda.amp.GradScaler()

    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint["model_state_dict"])
        optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
        scaler.load_state_dict(checkpoint["scaler_state_dict"])
        start_epoch = checkpoint["epoch"] + 1
        best_metric = checkpoint.get("best_metric", -1)
        best_metric_epoch = checkpoint.get("best_metric_epoch", -1)
        print(f"Resumed training from epoch {start_epoch}")
        log_to_file(f"Resumed training from epoch {start_epoch}")

    max_epochs = 1000
    val_interval = 1
    patience = 300
    patience_counter = 0

    for epoch in range(start_epoch, max_epochs):
        print(f"Epoch {epoch + 1}/{max_epochs}")
        log_to_file(f"Epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
                loss = loss_function(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_loss += loss.item()
            step += 1

        epoch_loss /= step
        writer.add_scalar("Loss/train", epoch_loss, epoch)
        log_to_file(f"Train Loss: {epoch_loss:.4f}")

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                dice_metric.reset()
                val_loss = 0
                val_step = 0
                for val_data in val_loader:
                    val_inputs = val_data["image"].to(device)
                    val_labels = val_data["label"].to(device)
                    with torch.cuda.amp.autocast():
                        val_outputs = torch.sigmoid(model(val_inputs))
                        loss = loss_function(val_outputs, val_labels)
                    val_loss += loss.item()
                    val_outputs = (val_outputs > 0.5).float()
                    dice_metric(y_pred=val_outputs, y=val_labels)
                    val_step += 1
                val_metric = dice_metric.aggregate().item()
                dice_metric.reset()

                writer.add_scalar("Loss/val", val_loss / val_step, epoch)
                writer.add_scalar("Dice/val", val_metric, epoch)
                log_to_file(f"Val Loss: {val_loss / val_step:.4f}, Val Dice: {val_metric:.4f}")

                if val_metric > best_metric:
                    best_metric = val_metric
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(model_dir, "best_model.pth"))
                    print(f"Saved new best model at epoch {epoch+1} with Dice: {val_metric:.4f}")
                    log_to_file(f"Saved best model at epoch {epoch+1} with Dice: {val_metric:.4f}")
                    patience_counter = 0
                else:
                    patience_counter += 1
                    print(f"No improvement. Patience: {patience_counter}/{patience}")
                    log_to_file(f"No improvement. Patience: {patience_counter}/{patience}")

                torch.save({
                    "epoch": epoch,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "scaler_state_dict": scaler.state_dict(),
                    "best_metric": best_metric,
                    "best_metric_epoch": best_metric_epoch
                }, checkpoint_path)
                log_to_file(f"Checkpoint saved at epoch {epoch+1}")

        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            log_to_file(f"Early stopping triggered at epoch {epoch+1}")
            break

    total_time = time.time() - start_time
    print(f"Training complete. Best Dice: {best_metric:.4f} at epoch {best_metric_epoch}")
    log_to_file(f"Training complete. Best Dice: {best_metric:.4f} at epoch {best_metric_epoch}")
    writer.close()
# Out:
# Epoch 1/1000
# /tmp/ipykernel_49978/1274637762.py:17: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /tmp/ipykernel_49978/1274637762.py:44: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /tmp/ipykernel_49978/1274637762.py:66: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Saved new best model at epoch 1 with Dice: 0.0015
# Epoch 2/1000
# Saved new best model at epoch 2 with Dice: 0.0019
# Epoch 3/1000
# Saved new best model at epoch 3 with Dice: 0.0022
# Epoch 4/1000
# Saved new best model at epoch 4 with Dice: 0.0024
# Epoch 5/1000
# Saved new best model at epoch 5 with Dice: 0.0025
# Epoch 6/1000
# Saved new best model at epoch 6 with Dice: 0.0030
# Epoch 7/1000
# Saved new best model at epoch 7 with Dice: 0.0030
# Epoch 8/1000
# Saved new best model at epoch 8 with Dice: 0.0032
# Epoch 9/1000
# Saved new best model at epoch 9 with Dice: 0.0036
# Epoch 10/1000
# No improvement. Patience: 1/300
# Epoch 11/1000
# No improvement. Patience: 2/300
# Epoch 12/1000
# No improvement. Patience: 3/300
# Epoch 13/1000
# No improvement. Patience: 4/300
# Epoch 14/1000
# No improvement. Patience: 5/300
# Epoch 15/1000
# Saved new best model at epoch 15 with Dice: 0.0041
# Epoch 16/1000
# No improvement. Patience: 1/300
# Epoch 17/1000
# No improvement. Patience: 2/300
# Epoch 18/1000
# No improvement. Patience: 3/300
# Epoch 19/1000
# No improvement. Patience: 4/300
# Epoch 20/1000
# No improvement. Patience: 5/300
# Epoch 21/1000
# No improvement. Patience: 6/300
# Epoch 22/1000
# No improvement. Patience: 7/300
# Epoch 23/1000
# Saved new best model at epoch 23 with Dice: 0.0043
# Epoch 24/1000
# Saved new best model at epoch 24 with Dice: 0.0048
# Epoch 25/1000
# No improvement. Patience: 1/300
# Epoch 26/1000
# Saved new best model at epoch 26 with Dice: 0.0048
# Epoch 27/1000
# Saved new best model at epoch 27 with Dice: 0.0049
# Epoch 28/1000
# No improvement. Patience: 1/300
# Epoch 29/1000
# No improvement. Patience: 2/300
# Epoch 30/1000
# Saved new best model at epoch 30 with Dice: 0.0051
# Epoch 31/1000
# No improvement. Patience: 1/300
# Epoch 32/1000
# Saved new best model at epoch 32 with Dice: 0.0058
# Epoch 33/1000
# No improvement. Patience: 1/300
# Epoch 34/1000
# No improvement. Patience: 2/300
# Epoch 35/1000
# No improvement. Patience: 3/300
# Epoch 36/1000
# No improvement. Patience: 4/300
# Epoch 37/1000
# No improvement. Patience: 5/300
# Epoch 38/1000
# No improvement. Patience: 6/300
# Epoch 39/1000
# Saved new best model at epoch 39 with Dice: 0.0060
# Epoch 40/1000
# No improvement. Patience: 1/300
# Epoch 41/1000
# No improvement. Patience: 2/300
# Epoch 42/1000
# No improvement. Patience: 3/300
# Epoch 43/1000
# Saved new best model at epoch 43 with Dice: 0.0060
# Epoch 44/1000
# No improvement. Patience: 1/300
# Epoch 45/1000
# No improvement. Patience: 2/300
# Epoch 46/1000
# No improvement. Patience: 3/300
# Epoch 47/1000
# No improvement. Patience: 4/300
# Epoch 48/1000
# No improvement. Patience: 5/300
# Epoch 49/1000
# No improvement. Patience: 6/300
# Epoch 50/1000
# No improvement. Patience: 7/300
# Epoch 51/1000
# No improvement. Patience: 8/300
# Epoch 52/1000
# Saved new best model at epoch 52 with Dice: 0.0061
# Epoch 53/1000
# No improvement. Patience: 1/300
# Epoch 54/1000
# No improvement. Patience: 2/300
# Epoch 55/1000
# No improvement. Patience: 3/300
# Epoch 56/1000
# Saved new best model at epoch 56 with Dice: 0.0063
# Epoch 57/1000
# No improvement. Patience: 1/300
# Epoch 58/1000
# Saved new best model at epoch 58 with Dice: 0.0063
# Epoch 59/1000
# No improvement. Patience: 1/300
# Epoch 60/1000
# No improvement. Patience: 2/300
# Epoch 61/1000
# No improvement. Patience: 3/300
# Epoch 62/1000
# Saved new best model at epoch 62 with Dice: 0.0063
# Epoch 63/1000
# No improvement. Patience: 1/300
# Epoch 64/1000
# No improvement. Patience: 2/300
# Epoch 65/1000
# No improvement. Patience: 3/300
# Epoch 66/1000
# No improvement. Patience: 4/300
# Epoch 67/1000
# No improvement. Patience: 5/300
# Epoch 68/1000
# No improvement. Patience: 6/300
# Epoch 69/1000
# No improvement. Patience: 7/300
# Epoch 70/1000
# No improvement. Patience: 8/300
# Epoch 71/1000
# No improvement. Patience: 9/300
# Epoch 72/1000
# No improvement. Patience: 10/300
# Epoch 73/1000
# No improvement. Patience: 11/300
# Epoch 74/1000
# No improvement. Patience: 12/300
# Epoch 75/1000
# No improvement. Patience: 13/300
# Epoch 76/1000
# No improvement. Patience: 14/300
# Epoch 77/1000
# No improvement. Patience: 15/300
# Epoch 78/1000
# No improvement. Patience: 16/300
# Epoch 79/1000
# No improvement. Patience: 17/300
# Epoch 80/1000
# No improvement. Patience: 18/300
# Epoch 81/1000
# No improvement. Patience: 19/300
# Epoch 82/1000
# No improvement. Patience: 20/300
# Epoch 83/1000
# No improvement. Patience: 21/300
# Epoch 84/1000
# No improvement. Patience: 22/300
# Epoch 85/1000
# No improvement. Patience: 23/300
# Epoch 86/1000
# No improvement. Patience: 24/300
# Epoch 87/1000
# No improvement. Patience: 25/300
# Epoch 88/1000
# No improvement. Patience: 26/300
# Epoch 89/1000
# No improvement. Patience: 27/300
# Epoch 90/1000
# No improvement. Patience: 28/300
# Epoch 91/1000
# No improvement. Patience: 29/300
# Epoch 92/1000
# No improvement. Patience: 30/300
# Epoch 93/1000
# No improvement. Patience: 31/300
# Epoch 94/1000
# No improvement. Patience: 32/300
# Epoch 95/1000
# No improvement. Patience: 33/300
# Epoch 96/1000
# No improvement. Patience: 34/300
# Epoch 97/1000
# No improvement. Patience: 35/300
# Epoch 98/1000
# No improvement. Patience: 36/300
# Epoch 99/1000
# No improvement. Patience: 37/300
# Epoch 100/1000
# No improvement. Patience: 38/300
# Epoch 101/1000
# No improvement. Patience: 39/300
# Epoch 102/1000
# No improvement. Patience: 40/300
# Epoch 103/1000
# Saved new best model at epoch 103 with Dice: 0.0066
# Epoch 104/1000
# No improvement. Patience: 1/300
# Epoch 105/1000
# No improvement. Patience: 2/300
# Epoch 106/1000
# No improvement. Patience: 3/300
# Epoch 107/1000
# No improvement. Patience: 4/300
# Epoch 108/1000
# No improvement. Patience: 5/300
# Epoch 109/1000
# No improvement. Patience: 6/300
# Epoch 110/1000
# No improvement. Patience: 7/300
# Epoch 111/1000
# No improvement. Patience: 8/300
# Epoch 112/1000
# No improvement. Patience: 9/300
# Epoch 113/1000
# No improvement. Patience: 10/300
# Epoch 114/1000
# No improvement. Patience: 11/300
# Epoch 115/1000
# No improvement. Patience: 12/300
# Epoch 116/1000
# Saved new best model at epoch 116 with Dice: 0.0066
# Epoch 117/1000
# No improvement. Patience: 1/300
# Epoch 118/1000
# Saved new best model at epoch 118 with Dice: 0.0068
# Epoch 119/1000
# No improvement. Patience: 1/300
# Epoch 120/1000
# No improvement. Patience: 2/300
# Epoch 121/1000
# No improvement. Patience: 3/300
# Epoch 122/1000
# No improvement. Patience: 4/300
# Epoch 123/1000
# No improvement. Patience: 5/300
# Epoch 124/1000
# No improvement. Patience: 6/300
# Epoch 125/1000
# Saved new best model at epoch 125 with Dice: 0.0071
# Epoch 126/1000
# Saved new best model at epoch 126 with Dice: 0.0075
# Epoch 127/1000
# No improvement. Patience: 1/300
# Epoch 128/1000
# No improvement. Patience: 2/300
# Epoch 129/1000
# No improvement. Patience: 3/300
# Epoch 130/1000
# No improvement. Patience: 4/300
# Epoch 131/1000
# No improvement. Patience: 5/300
# Epoch 132/1000
# No improvement. Patience: 6/300
# Epoch 133/1000
# No improvement. Patience: 7/300
# Epoch 134/1000
# No improvement. Patience: 8/300
# Epoch 135/1000
# Saved new best model at epoch 135 with Dice: 0.0078
# Epoch 136/1000
# No improvement. Patience: 1/300
# Epoch 137/1000
# No improvement. Patience: 2/300
# Epoch 138/1000
# No improvement. Patience: 3/300
# Epoch 139/1000
# No improvement. Patience: 4/300
# Epoch 140/1000
# Saved new best model at epoch 140 with Dice: 0.0082
# Epoch 141/1000
# No improvement. Patience: 1/300
# Epoch 142/1000
# No improvement. Patience: 2/300
# Epoch 143/1000
# No improvement. Patience: 3/300
# Epoch 144/1000
# No improvement. Patience: 4/300
# Epoch 145/1000
# No improvement. Patience: 5/300
# Epoch 146/1000
# No improvement. Patience: 6/300
# Epoch 147/1000
# No improvement. Patience: 7/300
# Epoch 148/1000
# No improvement. Patience: 8/300
# Epoch 149/1000
# Saved new best model at epoch 149 with Dice: 0.0084
# Epoch 150/1000
# No improvement. Patience: 1/300
# Epoch 151/1000
# Saved new best model at epoch 151 with Dice: 0.0088
# Epoch 152/1000
# No improvement. Patience: 1/300
# Epoch 153/1000
# No improvement. Patience: 2/300
# Epoch 154/1000
# Saved new best model at epoch 154 with Dice: 0.0092
# Epoch 155/1000
# No improvement. Patience: 1/300
# Epoch 156/1000
# No improvement. Patience: 2/300
# Epoch 157/1000
# No improvement. Patience: 3/300
# Epoch 158/1000
# No improvement. Patience: 4/300
# Epoch 159/1000
# Saved new best model at epoch 159 with Dice: 0.0095
# Epoch 160/1000
# No improvement. Patience: 1/300
# Epoch 161/1000
# No improvement. Patience: 2/300
# Epoch 162/1000
# Saved new best model at epoch 162 with Dice: 0.0106
# Epoch 163/1000
# No improvement. Patience: 1/300
# Epoch 164/1000
# No improvement. Patience: 2/300
# Epoch 165/1000
# No improvement. Patience: 3/300
# Epoch 166/1000
# Saved new best model at epoch 166 with Dice: 0.0122
# Epoch 167/1000
# No improvement. Patience: 1/300
# Epoch 168/1000
# No improvement. Patience: 2/300
# Epoch 169/1000
# No improvement. Patience: 3/300
# Epoch 170/1000
# No improvement. Patience: 4/300
# Epoch 171/1000
# No improvement. Patience: 5/300
# Epoch 172/1000
# No improvement. Patience: 6/300
# Epoch 173/1000
# No improvement. Patience: 7/300
# Epoch 174/1000
# No improvement. Patience: 8/300
# Epoch 175/1000
# No improvement. Patience: 9/300
# Epoch 176/1000
# Saved new best model at epoch 176 with Dice: 0.0123
# Epoch 177/1000
# No improvement. Patience: 1/300
# Epoch 178/1000
# No improvement. Patience: 2/300
# Epoch 179/1000
# No improvement. Patience: 3/300
# Epoch 180/1000
# No improvement. Patience: 4/300
# Epoch 181/1000
# Saved new best model at epoch 181 with Dice: 0.0132
# Epoch 182/1000
# No improvement. Patience: 1/300
# Epoch 183/1000
# No improvement. Patience: 2/300
# Epoch 184/1000
# No improvement. Patience: 3/300
# Epoch 185/1000
# No improvement. Patience: 4/300
# Epoch 186/1000
# Saved new best model at epoch 186 with Dice: 0.0142
# Epoch 187/1000
# No improvement. Patience: 1/300
# Epoch 188/1000
# No improvement. Patience: 2/300
# Epoch 189/1000
# No improvement. Patience: 3/300
# Epoch 190/1000
# Saved new best model at epoch 190 with Dice: 0.0154
# Epoch 191/1000
# No improvement. Patience: 1/300
# Epoch 192/1000
# No improvement. Patience: 2/300
# Epoch 193/1000
# No improvement. Patience: 3/300
# Epoch 194/1000
# No improvement. Patience: 4/300
# Epoch 195/1000
# No improvement. Patience: 5/300
# Epoch 196/1000
# No improvement. Patience: 6/300
# Epoch 197/1000
# No improvement. Patience: 7/300
# Epoch 198/1000
# Saved new best model at epoch 198 with Dice: 0.0159
# Epoch 199/1000
# No improvement. Patience: 1/300
# Epoch 200/1000
# No improvement. Patience: 2/300
# Epoch 201/1000
# No improvement. Patience: 3/300
# Epoch 202/1000
# No improvement. Patience: 4/300
# Epoch 203/1000
# No improvement. Patience: 5/300
# Epoch 204/1000
# No improvement. Patience: 6/300
# Epoch 205/1000
# No improvement. Patience: 7/300
# Epoch 206/1000
# No improvement. Patience: 8/300
# Epoch 207/1000
# Saved new best model at epoch 207 with Dice: 0.0173
# Epoch 208/1000
# No improvement. Patience: 1/300
# Epoch 209/1000
# Saved new best model at epoch 209 with Dice: 0.0190
# Epoch 210/1000
# Saved new best model at epoch 210 with Dice: 0.0191
# Epoch 211/1000
# No improvement. Patience: 1/300
# Epoch 212/1000
# No improvement. Patience: 2/300
# Epoch 213/1000
# No improvement. Patience: 3/300
# Epoch 214/1000
# No improvement. Patience: 4/300
# Epoch 215/1000
# No improvement. Patience: 5/300
# Epoch 216/1000
# No improvement. Patience: 6/300
# Epoch 217/1000
# No improvement. Patience: 7/300
# Epoch 218/1000
# No improvement. Patience: 8/300
# Epoch 219/1000
