# %%
import os
import glob
import torch
from torch.utils.tensorboard import SummaryWriter
from monai.transforms import (
    Compose, LoadImaged, Spacingd, Orientationd,
    ScaleIntensityRanged, CropForegroundd, RandCropByPosNegLabeld,
    RandFlipd, RandRotate90d, EnsureTyped, EnsureChannelFirstd, DivisiblePadd
)
from monai.data import DataLoader, CacheDataset, decollate_batch
from monai.networks.nets import AttentionUnet
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
import time
from datetime import datetime

# %%
# === Setup path ===
root_dir = "/mrhung_nguyen_minh_quang_108/workspace/train/nnUNet_raw/Dataset015_lungTumor"
images = sorted(glob.glob(os.path.join(root_dir, "imagesTr", "*.nii.gz")))
labels = sorted(glob.glob(os.path.join(root_dir, "labelsTr", "*.nii.gz")))

model_dir = "./saved_models"
log_dir = "./runs/AttenUNet_lung"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

log_file = os.path.join(log_dir, "training_log.txt")
def log_to_file(message, file_path=log_file):
    with open(file_path, "a") as f:
        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        f.write(f"[{timestamp}] {message}\n")

# %%
def calculate_metrics(y_pred, y_true, smooth=1e-6):
    """
    Calculate IoU, Precision, Recall, and Dice metrics
    Args:
        y_pred: prediction tensor (after threshold)
        y_true: target tensor
        smooth: smoothing factor to avoid division by zero
    Returns:
        dict containing IoU, Precision, Recall, and Dice values
    """
    y_pred = y_pred.flatten()
    y_true = y_true.flatten()
    
    # Calculate intersection and union
    intersection = (y_pred * y_true).sum()
    union = y_pred.sum() + y_true.sum() - intersection
    
    # True positives, false positives, false negatives
    tp = intersection
    fp = y_pred.sum() - tp
    fn = y_true.sum() - tp
    
    # Calculate metrics
    iou = (intersection + smooth) / (union + smooth)
    precision = (tp + smooth) / (tp + fp + smooth)
    recall = (tp + smooth) / (tp + fn + smooth)
    dice = (2 * tp + smooth) / (2 * tp + fp + fn + smooth)
    
    return {
        "iou": iou.item(),
        "precision": precision.item(),
        "recall": recall.item(),
        "dice": dice.item()
    }

# %%
# === Resume from checkpoint if exists ===
checkpoint_path = os.path.join(model_dir, "last_checkpoint.pth")
start_epoch = 0
best_metric = -1
best_metric_epoch = -1

writer = SummaryWriter(log_dir=log_dir)
data_dicts = [{"image": img, "label": lbl} for img, lbl in zip(images, labels)]

# %%
val_frac = 0.2
val_split = int(len(data_dicts) * (1 - val_frac))
train_files = data_dicts[:val_split]
val_files = data_dicts[val_split:]

# %%
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(2.0, 2.0, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=400, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image", allow_smaller=True),
    DivisiblePadd(keys=["image", "label"], k=16),
    RandCropByPosNegLabeld(
        keys=["image", "label"], label_key="label", spatial_size=(96, 96, 96),
        pos=1, neg=1, num_samples=2, image_key="image", image_threshold=0
    ),
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
    RandRotate90d(keys=["image", "label"], prob=0.5, max_k=3),
    EnsureTyped(keys=["image", "label"]),
])

# %%
val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    Spacingd(keys=["image", "label"], pixdim=(2.0, 2.0, 2.0), mode=("bilinear", "nearest")),
    Orientationd(keys=["image", "label"], axcodes="RAS"),
    ScaleIntensityRanged(keys=["image"], a_min=-1000, a_max=400, b_min=0.0, b_max=1.0, clip=True),
    CropForegroundd(keys=["image", "label"], source_key="image", allow_smaller=True),
    DivisiblePadd(keys=["image", "label"], k=16),
    EnsureTyped(keys=["image", "label"]),
])

# %%
    train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=2)
    train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=2, persistent_workers=True, pin_memory=True)

    val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=2)
    val_loader = DataLoader(val_ds, batch_size=1, num_workers=2, persistent_workers=True, pin_memory=True)
# Out:
# Loading dataset: 100%|██████████| 92/92 [08:03<00:00,  5.25s/it]
# Loading dataset: 100%|██████████| 23/23 [01:51<00:00,  4.86s/it]

# %%
if __name__ == "__main__":
    start_time = time.time()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = AttentionUnet(
        spatial_dims=3,
        in_channels=1,
        out_channels=1,
        channels=(16, 32, 64, 128, 256),
        strides=(2, 2, 2, 2),
    ).to(device)

    loss_function = DiceLoss(sigmoid=True)
    optimizer = torch.optim.Adam(model.parameters(), 1e-4)
    dice_metric = DiceMetric(include_background=False, reduction="mean")
    scaler = torch.cuda.amp.GradScaler()

    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint["model_state_dict"])
        optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
        scaler.load_state_dict(checkpoint["scaler_state_dict"])
        start_epoch = checkpoint["epoch"] + 1
        best_metric = checkpoint.get("best_metric", -1)
        best_metric_epoch = checkpoint.get("best_metric_epoch", -1)
        print(f"Resumed training from epoch {start_epoch}")
        log_to_file(f"Resumed training from epoch {start_epoch}")

    max_epochs = 1000
    val_interval = 1
    patience = 300
    patience_counter = 0

    for epoch in range(start_epoch, max_epochs):
        print(f"Epoch {epoch + 1}/{max_epochs}")
        log_to_file(f"Epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
                loss = loss_function(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_loss += loss.item()
            step += 1

        epoch_loss /= step
        writer.add_scalar("Loss/train", epoch_loss, epoch)
        log_to_file(f"Train Loss: {epoch_loss:.4f}")

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                dice_metric.reset()
                val_loss = 0
                val_step = 0
                val_metrics = {"iou": 0, "precision": 0, "recall": 0, "dice": 0}
                
                for val_data in val_loader:
                    val_inputs = val_data["image"].to(device)
                    val_labels = val_data["label"].to(device)
                    with torch.cuda.amp.autocast():
                        val_outputs = torch.sigmoid(model(val_inputs))
                        loss = loss_function(val_outputs, val_labels)
                    val_loss += loss.item()
                    
                    # Apply threshold to get binary predictions
                    val_outputs_binary = (val_outputs > 0.5).float()
                    
                    # Calculate metrics using MONAI's DiceMetric
                    dice_metric(y_pred=val_outputs_binary, y=val_labels)
                    
                    # Calculate additional metrics (IoU, Precision, Recall)
                    batch_metrics = calculate_metrics(val_outputs_binary, val_labels)
                    for key in val_metrics:
                        val_metrics[key] += batch_metrics[key]
                    
                    val_step += 1
                
                # Get average metrics
                for key in val_metrics:
                    val_metrics[key] /= val_step
                
                val_metric = dice_metric.aggregate().item()  # MONAI's dice metric
                dice_metric.reset()

                # Log metrics to tensorboard
                writer.add_scalar("Loss/val", val_loss / val_step, epoch)
                writer.add_scalar("Dice/val", val_metric, epoch)
                writer.add_scalar("IoU/val", val_metrics["iou"], epoch)
                writer.add_scalar("Precision/val", val_metrics["precision"], epoch)
                writer.add_scalar("Recall/val", val_metrics["recall"], epoch)
                
                # Log metrics to file
                log_to_file(
                    f"Val Loss: {val_loss / val_step:.4f}, "
                    f"Val Dice: {val_metric:.4f}, "
                    f"Val IoU: {val_metrics['iou']:.4f}, "
                    f"Val Precision: {val_metrics['precision']:.4f}, "
                    f"Val Recall: {val_metrics['recall']:.4f}"
                )

                # Save best model based on Dice score
                if val_metric > best_metric:
                    best_metric = val_metric
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(model_dir, "best_model.pth"))
                    print(f"Saved new best model at epoch {epoch+1} with Dice: {val_metric:.4f}")
                    log_to_file(f"Saved best model at epoch {epoch+1} with Dice: {val_metric:.4f}")
                    patience_counter = 0
                else:
                    patience_counter += 1
                    print(f"No improvement. Patience: {patience_counter}/{patience}")
                    log_to_file(f"No improvement. Patience: {patience_counter}/{patience}")

                torch.save({
                    "epoch": epoch,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "scaler_state_dict": scaler.state_dict(),
                    "best_metric": best_metric,
                    "best_metric_epoch": best_metric_epoch,
                    "last_metrics": {
                        "dice": val_metric,
                        "iou": val_metrics["iou"],
                        "precision": val_metrics["precision"],
                        "recall": val_metrics["recall"]
                    }
                }, checkpoint_path)
                log_to_file(f"Checkpoint saved at epoch {epoch+1}")

        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            log_to_file(f"Early stopping triggered at epoch {epoch+1}")
            break

    total_time = time.time() - start_time
    print(f"Training complete. Best Dice: {best_metric:.4f} at epoch {best_metric_epoch}")
    log_to_file(f"Training complete. Best Dice: {best_metric:.4f} at epoch {best_metric_epoch}")
    log_to_file(f"Total training time: {total_time/60:.2f} minutes")
    writer.close()
# Out:
# Epoch 1/1000
# /tmp/ipykernel_7404/3596436179.py:15: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /tmp/ipykernel_7404/3596436179.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /tmp/ipykernel_7404/3596436179.py:66: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Saved new best model at epoch 1 with Dice: 0.0019
# Epoch 2/1000
# No improvement. Patience: 1/300
# Epoch 3/1000
# Saved new best model at epoch 3 with Dice: 0.0021
# Epoch 4/1000
# No improvement. Patience: 1/300
# Epoch 5/1000
# Saved new best model at epoch 5 with Dice: 0.0026
# Epoch 6/1000
# Saved new best model at epoch 6 with Dice: 0.0030
# Epoch 7/1000
# Saved new best model at epoch 7 with Dice: 0.0031
# Epoch 8/1000
# No improvement. Patience: 1/300
# Epoch 9/1000
# Saved new best model at epoch 9 with Dice: 0.0031
# Epoch 10/1000
# No improvement. Patience: 1/300
# Epoch 11/1000
# No improvement. Patience: 2/300
# Epoch 12/1000
# No improvement. Patience: 3/300
# Epoch 13/1000
# No improvement. Patience: 4/300
# Epoch 14/1000
# No improvement. Patience: 5/300
# Epoch 15/1000
# Saved new best model at epoch 15 with Dice: 0.0035
# Epoch 16/1000
# Saved new best model at epoch 16 with Dice: 0.0036
# Epoch 17/1000
# No improvement. Patience: 1/300
# Epoch 18/1000
# No improvement. Patience: 2/300
# Epoch 19/1000
# No improvement. Patience: 3/300
# Epoch 20/1000
# No improvement. Patience: 4/300
# Epoch 21/1000
# No improvement. Patience: 5/300
# Epoch 22/1000
# Saved new best model at epoch 22 with Dice: 0.0039
# Epoch 23/1000
# Saved new best model at epoch 23 with Dice: 0.0041
# Epoch 24/1000
# No improvement. Patience: 1/300
# Epoch 25/1000
# No improvement. Patience: 2/300
# Epoch 26/1000
# No improvement. Patience: 3/300
# Epoch 27/1000
# Saved new best model at epoch 27 with Dice: 0.0044
# Epoch 28/1000
# No improvement. Patience: 1/300
# Epoch 29/1000
# No improvement. Patience: 2/300
# Epoch 30/1000
# No improvement. Patience: 3/300
# Epoch 31/1000
# Saved new best model at epoch 31 with Dice: 0.0048
# Epoch 32/1000
# No improvement. Patience: 1/300
# Epoch 33/1000
# Saved new best model at epoch 33 with Dice: 0.0058
# Epoch 34/1000
# No improvement. Patience: 1/300
# Epoch 35/1000
# No improvement. Patience: 2/300
# Epoch 36/1000
# No improvement. Patience: 3/300
# Epoch 37/1000
# Saved new best model at epoch 37 with Dice: 0.0058
# Epoch 38/1000
# No improvement. Patience: 1/300
# Epoch 39/1000
# No improvement. Patience: 2/300
# Epoch 40/1000
# Saved new best model at epoch 40 with Dice: 0.0073
# Epoch 41/1000
# No improvement. Patience: 1/300
# Epoch 42/1000
# No improvement. Patience: 2/300
# Epoch 43/1000
# No improvement. Patience: 3/300
# Epoch 44/1000
# No improvement. Patience: 4/300
# Epoch 45/1000
# No improvement. Patience: 5/300
# Epoch 46/1000
# No improvement. Patience: 6/300
# Epoch 47/1000
# No improvement. Patience: 7/300
# Epoch 48/1000
# No improvement. Patience: 8/300
# Epoch 49/1000
# No improvement. Patience: 9/300
# Epoch 50/1000
# Saved new best model at epoch 50 with Dice: 0.0078
# Epoch 51/1000
# Saved new best model at epoch 51 with Dice: 0.0079
# Epoch 52/1000
# No improvement. Patience: 1/300
# Epoch 53/1000
# No improvement. Patience: 2/300
# Epoch 54/1000
# Saved new best model at epoch 54 with Dice: 0.0081
# Epoch 55/1000
# No improvement. Patience: 1/300
# Epoch 56/1000
# Saved new best model at epoch 56 with Dice: 0.0125
# Epoch 57/1000
# No improvement. Patience: 1/300
# Epoch 58/1000
# No improvement. Patience: 2/300
# Epoch 59/1000
# No improvement. Patience: 3/300
# Epoch 60/1000
# Saved new best model at epoch 60 with Dice: 0.0149
# Epoch 61/1000
# No improvement. Patience: 1/300
# Epoch 62/1000
# Saved new best model at epoch 62 with Dice: 0.0158
# Epoch 63/1000
# No improvement. Patience: 1/300
# Epoch 64/1000
# Saved new best model at epoch 64 with Dice: 0.0162
# Epoch 65/1000
# No improvement. Patience: 1/300
# Epoch 66/1000
# Saved new best model at epoch 66 with Dice: 0.0207
# Epoch 67/1000
# No improvement. Patience: 1/300
# Epoch 68/1000
# No improvement. Patience: 2/300
# Epoch 69/1000
# Saved new best model at epoch 69 with Dice: 0.0208
# Epoch 70/1000
# No improvement. Patience: 1/300
# Epoch 71/1000
# Saved new best model at epoch 71 with Dice: 0.0251
# Epoch 72/1000
# No improvement. Patience: 1/300
# Epoch 73/1000
# No improvement. Patience: 2/300
# Epoch 74/1000
# No improvement. Patience: 3/300
# Epoch 75/1000
# No improvement. Patience: 4/300
# Epoch 76/1000
# No improvement. Patience: 5/300
# Epoch 77/1000
# Saved new best model at epoch 77 with Dice: 0.0292
# Epoch 78/1000
# No improvement. Patience: 1/300
# Epoch 79/1000
# Saved new best model at epoch 79 with Dice: 0.0363
# Epoch 80/1000
# No improvement. Patience: 1/300
# Epoch 81/1000
# Saved new best model at epoch 81 with Dice: 0.0401
# Epoch 82/1000
# No improvement. Patience: 1/300
# Epoch 83/1000
# No improvement. Patience: 2/300
# Epoch 84/1000
# No improvement. Patience: 3/300
# Epoch 85/1000
# No improvement. Patience: 4/300
# Epoch 86/1000
# No improvement. Patience: 5/300
# Epoch 87/1000
# Saved new best model at epoch 87 with Dice: 0.0488
# Epoch 88/1000
# No improvement. Patience: 1/300
# Epoch 89/1000
# No improvement. Patience: 2/300
# Epoch 90/1000
# Saved new best model at epoch 90 with Dice: 0.0605
# Epoch 91/1000
# Saved new best model at epoch 91 with Dice: 0.0814
# Epoch 92/1000
# No improvement. Patience: 1/300
# Epoch 93/1000
# Saved new best model at epoch 93 with Dice: 0.0872
# Epoch 94/1000
# Saved new best model at epoch 94 with Dice: 0.1089
# Epoch 95/1000
# No improvement. Patience: 1/300
# Epoch 96/1000
# No improvement. Patience: 2/300
# Epoch 97/1000
# No improvement. Patience: 3/300
# Epoch 98/1000
# No improvement. Patience: 4/300
# Epoch 99/1000
# No improvement. Patience: 5/300
# Epoch 100/1000
# No improvement. Patience: 6/300
# Epoch 101/1000
# No improvement. Patience: 7/300
# Epoch 102/1000
# No improvement. Patience: 8/300
# Epoch 103/1000
# No improvement. Patience: 9/300
# Epoch 104/1000
# No improvement. Patience: 10/300
# Epoch 105/1000
# Saved new best model at epoch 105 with Dice: 0.1102
# Epoch 106/1000
# No improvement. Patience: 1/300
# Epoch 107/1000
# No improvement. Patience: 2/300
# Epoch 108/1000
# No improvement. Patience: 3/300
# Epoch 109/1000
# No improvement. Patience: 4/300
# Epoch 110/1000
# No improvement. Patience: 5/300
# Epoch 111/1000
# No improvement. Patience: 6/300
# Epoch 112/1000
# Saved new best model at epoch 112 with Dice: 0.1431
# Epoch 113/1000
# No improvement. Patience: 1/300
# Epoch 114/1000
# No improvement. Patience: 2/300
# Epoch 115/1000
# Saved new best model at epoch 115 with Dice: 0.1911
# Epoch 116/1000
# No improvement. Patience: 1/300
# Epoch 117/1000
# No improvement. Patience: 2/300
# Epoch 118/1000
# No improvement. Patience: 3/300
# Epoch 119/1000
# No improvement. Patience: 4/300
# Epoch 120/1000
# No improvement. Patience: 5/300
# Epoch 121/1000
# Saved new best model at epoch 121 with Dice: 0.2065
# Epoch 122/1000
# No improvement. Patience: 1/300
# Epoch 123/1000
# No improvement. Patience: 2/300
# Epoch 124/1000
# No improvement. Patience: 3/300
# Epoch 125/1000
# No improvement. Patience: 4/300
# Epoch 126/1000
# No improvement. Patience: 5/300
# Epoch 127/1000
# No improvement. Patience: 6/300
# Epoch 128/1000
# No improvement. Patience: 7/300
# Epoch 129/1000
# No improvement. Patience: 8/300
# Epoch 130/1000
# Saved new best model at epoch 130 with Dice: 0.2721
# Epoch 131/1000
# No improvement. Patience: 1/300
# Epoch 132/1000
# No improvement. Patience: 2/300
# Epoch 133/1000
# No improvement. Patience: 3/300
# Epoch 134/1000
# No improvement. Patience: 4/300
# Epoch 135/1000
# No improvement. Patience: 5/300
# Epoch 136/1000
# No improvement. Patience: 6/300
# Epoch 137/1000
# No improvement. Patience: 7/300
# Epoch 138/1000
# No improvement. Patience: 8/300
# Epoch 139/1000
# Saved new best model at epoch 139 with Dice: 0.2767
# Epoch 140/1000
# No improvement. Patience: 1/300
# Epoch 141/1000
# No improvement. Patience: 2/300
# Epoch 142/1000
# Saved new best model at epoch 142 with Dice: 0.3697
# Epoch 143/1000
# No improvement. Patience: 1/300
# Epoch 144/1000
# Saved new best model at epoch 144 with Dice: 0.3934
# Epoch 145/1000
# No improvement. Patience: 1/300
# Epoch 146/1000
# No improvement. Patience: 2/300
# Epoch 147/1000
# No improvement. Patience: 3/300
# Epoch 148/1000
# No improvement. Patience: 4/300
# Epoch 149/1000
# No improvement. Patience: 5/300
# Epoch 150/1000
# No improvement. Patience: 6/300
# Epoch 151/1000
# Saved new best model at epoch 151 with Dice: 0.4384
# Epoch 152/1000
# No improvement. Patience: 1/300
# Epoch 153/1000
# No improvement. Patience: 2/300
# Epoch 154/1000
# No improvement. Patience: 3/300
# Epoch 155/1000
# Saved new best model at epoch 155 with Dice: 0.4523
# Epoch 156/1000
# No improvement. Patience: 1/300
# Epoch 157/1000
# No improvement. Patience: 2/300
# Epoch 158/1000
# No improvement. Patience: 3/300
# Epoch 159/1000
# No improvement. Patience: 4/300
# Epoch 160/1000
# No improvement. Patience: 5/300
# Epoch 161/1000
# No improvement. Patience: 6/300
# Epoch 162/1000
# No improvement. Patience: 7/300
# Epoch 163/1000
# Saved new best model at epoch 163 with Dice: 0.4750
# Epoch 164/1000
# Saved new best model at epoch 164 with Dice: 0.4799
# Epoch 165/1000
# No improvement. Patience: 1/300
# Epoch 166/1000
# No improvement. Patience: 2/300
# Epoch 167/1000
# No improvement. Patience: 3/300
# Epoch 168/1000
# Saved new best model at epoch 168 with Dice: 0.5070
# Epoch 169/1000
# No improvement. Patience: 1/300
# Epoch 170/1000
# No improvement. Patience: 2/300
# Epoch 171/1000
# No improvement. Patience: 3/300
# Epoch 172/1000
# No improvement. Patience: 4/300
# Epoch 173/1000
# No improvement. Patience: 5/300
# Epoch 174/1000
# No improvement. Patience: 6/300
# Epoch 175/1000
# No improvement. Patience: 7/300
# Epoch 176/1000
# Saved new best model at epoch 176 with Dice: 0.5184
# Epoch 177/1000
# Saved new best model at epoch 177 with Dice: 0.5463
# Epoch 178/1000
# No improvement. Patience: 1/300
# Epoch 179/1000
# No improvement. Patience: 2/300
# Epoch 180/1000
# No improvement. Patience: 3/300
# Epoch 181/1000
# Saved new best model at epoch 181 with Dice: 0.5543
# Epoch 182/1000
# No improvement. Patience: 1/300
# Epoch 183/1000
# No improvement. Patience: 2/300
# Epoch 184/1000
# No improvement. Patience: 3/300
# Epoch 185/1000
# No improvement. Patience: 4/300
# Epoch 186/1000
# No improvement. Patience: 5/300
# Epoch 187/1000
# No improvement. Patience: 6/300
# Epoch 188/1000
# No improvement. Patience: 7/300
# Epoch 189/1000
# No improvement. Patience: 8/300
# Epoch 190/1000
# Saved new best model at epoch 190 with Dice: 0.5571
# Epoch 191/1000
# No improvement. Patience: 1/300
# Epoch 192/1000
# No improvement. Patience: 2/300
# Epoch 193/1000
# No improvement. Patience: 3/300
# Epoch 194/1000
# No improvement. Patience: 4/300
# Epoch 195/1000
# No improvement. Patience: 5/300
# Epoch 196/1000
# No improvement. Patience: 6/300
# Epoch 197/1000
# No improvement. Patience: 7/300
# Epoch 198/1000
# No improvement. Patience: 8/300
# Epoch 199/1000
# No improvement. Patience: 9/300
# Epoch 200/1000
# No improvement. Patience: 10/300
# Epoch 201/1000
# No improvement. Patience: 11/300
# Epoch 202/1000
# No improvement. Patience: 12/300
# Epoch 203/1000
# No improvement. Patience: 13/300
# Epoch 204/1000
# No improvement. Patience: 14/300
# Epoch 205/1000
# No improvement. Patience: 15/300
# Epoch 206/1000
# No improvement. Patience: 16/300
# Epoch 207/1000
# Saved new best model at epoch 207 with Dice: 0.5614
# Epoch 208/1000
# No improvement. Patience: 1/300
# Epoch 209/1000
# No improvement. Patience: 2/300
# Epoch 210/1000
# No improvement. Patience: 3/300
# Epoch 211/1000
# No improvement. Patience: 4/300
# Epoch 212/1000
# No improvement. Patience: 5/300
# Epoch 213/1000
# No improvement. Patience: 6/300
# Epoch 214/1000
# Saved new best model at epoch 214 with Dice: 0.5712
# Epoch 215/1000
# Saved new best model at epoch 215 with Dice: 0.5842
# Epoch 216/1000
# No improvement. Patience: 1/300
# Epoch 217/1000
# No improvement. Patience: 2/300
# Epoch 218/1000
# No improvement. Patience: 3/300
# Epoch 219/1000
# No improvement. Patience: 4/300
# Epoch 220/1000
# No improvement. Patience: 5/300
# Epoch 221/1000
# No improvement. Patience: 6/300
# Epoch 222/1000
# No improvement. Patience: 7/300
# Epoch 223/1000
# No improvement. Patience: 8/300
# Epoch 224/1000
# No improvement. Patience: 9/300
# Epoch 225/1000
# No improvement. Patience: 10/300
# Epoch 226/1000
# No improvement. Patience: 11/300
# Epoch 227/1000
# No improvement. Patience: 12/300
# Epoch 228/1000
# No improvement. Patience: 13/300
# Epoch 229/1000
# No improvement. Patience: 14/300
# Epoch 230/1000
# No improvement. Patience: 15/300
# Epoch 231/1000
# No improvement. Patience: 16/300
# Epoch 232/1000
# No improvement. Patience: 17/300
# Epoch 233/1000
# No improvement. Patience: 18/300
# Epoch 234/1000
# No improvement. Patience: 19/300
# Epoch 235/1000
# No improvement. Patience: 20/300
# Epoch 236/1000
# Saved new best model at epoch 236 with Dice: 0.6007
# Epoch 237/1000
# No improvement. Patience: 1/300
# Epoch 238/1000
# No improvement. Patience: 2/300
# Epoch 239/1000
# No improvement. Patience: 3/300
# Epoch 240/1000
# No improvement. Patience: 4/300
# Epoch 241/1000
# No improvement. Patience: 5/300
# Epoch 242/1000
# No improvement. Patience: 6/300
# Epoch 243/1000
# No improvement. Patience: 7/300
# Epoch 244/1000
# No improvement. Patience: 8/300
# Epoch 245/1000
# No improvement. Patience: 9/300
# Epoch 246/1000
# No improvement. Patience: 10/300
# Epoch 247/1000
# No improvement. Patience: 11/300
# Epoch 248/1000
# No improvement. Patience: 12/300
# Epoch 249/1000
# No improvement. Patience: 13/300
# Epoch 250/1000
# No improvement. Patience: 14/300
# Epoch 251/1000
# No improvement. Patience: 15/300
# Epoch 252/1000
# No improvement. Patience: 16/300
# Epoch 253/1000
# No improvement. Patience: 17/300
# Epoch 254/1000
# No improvement. Patience: 18/300
# Epoch 255/1000
# No improvement. Patience: 19/300
# Epoch 256/1000
# No improvement. Patience: 20/300
# Epoch 257/1000
# No improvement. Patience: 21/300
# Epoch 258/1000
# No improvement. Patience: 22/300
# Epoch 259/1000
# No improvement. Patience: 23/300
# Epoch 260/1000
# No improvement. Patience: 24/300
# Epoch 261/1000
# No improvement. Patience: 25/300
# Epoch 262/1000
# No improvement. Patience: 26/300
# Epoch 263/1000
# No improvement. Patience: 27/300
# Epoch 264/1000
# No improvement. Patience: 28/300
# Epoch 265/1000
# No improvement. Patience: 29/300
# Epoch 266/1000
# No improvement. Patience: 30/300
# Epoch 267/1000
# No improvement. Patience: 31/300
# Epoch 268/1000
# No improvement. Patience: 32/300
# Epoch 269/1000
# No improvement. Patience: 33/300
# Epoch 270/1000
# No improvement. Patience: 34/300
# Epoch 271/1000
# No improvement. Patience: 35/300
# Epoch 272/1000
# No improvement. Patience: 36/300
# Epoch 273/1000
# No improvement. Patience: 37/300
# Epoch 274/1000
# No improvement. Patience: 38/300
# Epoch 275/1000
# No improvement. Patience: 39/300
# Epoch 276/1000
# No improvement. Patience: 40/300
# Epoch 277/1000
# No improvement. Patience: 41/300
# Epoch 278/1000
# No improvement. Patience: 42/300
# Epoch 279/1000
# No improvement. Patience: 43/300
# Epoch 280/1000
# No improvement. Patience: 44/300
# Epoch 281/1000
# No improvement. Patience: 45/300
# Epoch 282/1000
# No improvement. Patience: 46/300
# Epoch 283/1000
# No improvement. Patience: 47/300
# Epoch 284/1000
# No improvement. Patience: 48/300
# Epoch 285/1000
# No improvement. Patience: 49/300
# Epoch 286/1000
# Saved new best model at epoch 286 with Dice: 0.6175
# Epoch 287/1000
# No improvement. Patience: 1/300
# Epoch 288/1000
# No improvement. Patience: 2/300
# Epoch 289/1000
# No improvement. Patience: 3/300
# Epoch 290/1000
# No improvement. Patience: 4/300
# Epoch 291/1000
# No improvement. Patience: 5/300
# Epoch 292/1000
# No improvement. Patience: 6/300
# Epoch 293/1000
# No improvement. Patience: 7/300
# Epoch 294/1000
# No improvement. Patience: 8/300
# Epoch 295/1000
# No improvement. Patience: 9/300
# Epoch 296/1000
# No improvement. Patience: 10/300
# Epoch 297/1000
# No improvement. Patience: 11/300
# Epoch 298/1000
# No improvement. Patience: 12/300
# Epoch 299/1000
# No improvement. Patience: 13/300
# Epoch 300/1000
# No improvement. Patience: 14/300
# Epoch 301/1000
# No improvement. Patience: 15/300
# Epoch 302/1000
# No improvement. Patience: 16/300
# Epoch 303/1000
# No improvement. Patience: 17/300
# Epoch 304/1000
# No improvement. Patience: 18/300
# Epoch 305/1000
# No improvement. Patience: 19/300
# Epoch 306/1000
# No improvement. Patience: 20/300
# Epoch 307/1000
# No improvement. Patience: 21/300
# Epoch 308/1000
# No improvement. Patience: 22/300
# Epoch 309/1000
# No improvement. Patience: 23/300
# Epoch 310/1000
# No improvement. Patience: 24/300
# Epoch 311/1000
# No improvement. Patience: 25/300
# Epoch 312/1000
# No improvement. Patience: 26/300
# Epoch 313/1000
# No improvement. Patience: 27/300
# Epoch 314/1000
# No improvement. Patience: 28/300
# Epoch 315/1000
# No improvement. Patience: 29/300
# Epoch 316/1000
# No improvement. Patience: 30/300
# Epoch 317/1000
# No improvement. Patience: 31/300
# Epoch 318/1000
# No improvement. Patience: 32/300
# Epoch 319/1000
# No improvement. Patience: 33/300
# Epoch 320/1000
# No improvement. Patience: 34/300
# Epoch 321/1000
# No improvement. Patience: 35/300
# Epoch 322/1000
# No improvement. Patience: 36/300
# Epoch 323/1000
# No improvement. Patience: 37/300
# Epoch 324/1000
# No improvement. Patience: 38/300
# Epoch 325/1000
# No improvement. Patience: 39/300
# Epoch 326/1000
# No improvement. Patience: 40/300
# Epoch 327/1000
# No improvement. Patience: 41/300
# Epoch 328/1000
# No improvement. Patience: 42/300
# Epoch 329/1000
# No improvement. Patience: 43/300
# Epoch 330/1000
# No improvement. Patience: 44/300
# Epoch 331/1000
# No improvement. Patience: 45/300
# Epoch 332/1000
# No improvement. Patience: 46/300
# Epoch 333/1000
# No improvement. Patience: 47/300
# Epoch 334/1000
# No improvement. Patience: 48/300
# Epoch 335/1000
# No improvement. Patience: 49/300
# Epoch 336/1000
# No improvement. Patience: 50/300
# Epoch 337/1000
# No improvement. Patience: 51/300
# Epoch 338/1000
# No improvement. Patience: 52/300
# Epoch 339/1000
# Saved new best model at epoch 339 with Dice: 0.6253
# Epoch 340/1000
# No improvement. Patience: 1/300
# Epoch 341/1000
# No improvement. Patience: 2/300
# Epoch 342/1000
# No improvement. Patience: 3/300
# Epoch 343/1000
# No improvement. Patience: 4/300
# Epoch 344/1000
# No improvement. Patience: 5/300
# Epoch 345/1000
# No improvement. Patience: 6/300
# Epoch 346/1000
# No improvement. Patience: 7/300
# Epoch 347/1000
# No improvement. Patience: 8/300
# Epoch 348/1000
# No improvement. Patience: 9/300
# Epoch 349/1000
# No improvement. Patience: 10/300
# Epoch 350/1000
# No improvement. Patience: 11/300
# Epoch 351/1000
# No improvement. Patience: 12/300
# Epoch 352/1000
# No improvement. Patience: 13/300
# Epoch 353/1000
# No improvement. Patience: 14/300
# Epoch 354/1000
# No improvement. Patience: 15/300
# Epoch 355/1000
# No improvement. Patience: 16/300
# Epoch 356/1000
# No improvement. Patience: 17/300
# Epoch 357/1000
# No improvement. Patience: 18/300
# Epoch 358/1000
# No improvement. Patience: 19/300
# Epoch 359/1000
# No improvement. Patience: 20/300
# Epoch 360/1000
# No improvement. Patience: 21/300
# Epoch 361/1000
# No improvement. Patience: 22/300
# Epoch 362/1000
# No improvement. Patience: 23/300
# Epoch 363/1000
# No improvement. Patience: 24/300
# Epoch 364/1000
# No improvement. Patience: 25/300
# Epoch 365/1000
# No improvement. Patience: 26/300
# Epoch 366/1000
# No improvement. Patience: 27/300
# Epoch 367/1000
# No improvement. Patience: 28/300
# Epoch 368/1000
# No improvement. Patience: 29/300
# Epoch 369/1000
# No improvement. Patience: 30/300
# Epoch 370/1000
# No improvement. Patience: 31/300
# Epoch 371/1000
# No improvement. Patience: 32/300
# Epoch 372/1000
# No improvement. Patience: 33/300
# Epoch 373/1000
# No improvement. Patience: 34/300
# Epoch 374/1000
# No improvement. Patience: 35/300
# Epoch 375/1000
# No improvement. Patience: 36/300
# Epoch 376/1000
# No improvement. Patience: 37/300
# Epoch 377/1000
# No improvement. Patience: 38/300
# Epoch 378/1000
# No improvement. Patience: 39/300
# Epoch 379/1000
# No improvement. Patience: 40/300
# Epoch 380/1000
# No improvement. Patience: 41/300
# Epoch 381/1000
# No improvement. Patience: 42/300
# Epoch 382/1000
# No improvement. Patience: 43/300
# Epoch 383/1000
# No improvement. Patience: 44/300
# Epoch 384/1000
# No improvement. Patience: 45/300
# Epoch 385/1000
# No improvement. Patience: 46/300
# Epoch 386/1000
# No improvement. Patience: 47/300
# Epoch 387/1000
# No improvement. Patience: 48/300
# Epoch 388/1000
# No improvement. Patience: 49/300
# Epoch 389/1000
# No improvement. Patience: 50/300
# Epoch 390/1000
# No improvement. Patience: 51/300
# Epoch 391/1000
# No improvement. Patience: 52/300
# Epoch 392/1000
# No improvement. Patience: 53/300
# Epoch 393/1000
# No improvement. Patience: 54/300
# Epoch 394/1000
# No improvement. Patience: 55/300
# Epoch 395/1000
# No improvement. Patience: 56/300
# Epoch 396/1000
# No improvement. Patience: 57/300
# Epoch 397/1000
# No improvement. Patience: 58/300
# Epoch 398/1000
# No improvement. Patience: 59/300
# Epoch 399/1000
# No improvement. Patience: 60/300
# Epoch 400/1000
# No improvement. Patience: 61/300
# Epoch 401/1000
# No improvement. Patience: 62/300
# Epoch 402/1000
# No improvement. Patience: 63/300
# Epoch 403/1000
# No improvement. Patience: 64/300
# Epoch 404/1000
# No improvement. Patience: 65/300
# Epoch 405/1000
# No improvement. Patience: 66/300
# Epoch 406/1000
# No improvement. Patience: 67/300
# Epoch 407/1000
# No improvement. Patience: 68/300
# Epoch 408/1000
# No improvement. Patience: 69/300
# Epoch 409/1000
# No improvement. Patience: 70/300
# Epoch 410/1000
# No improvement. Patience: 71/300
# Epoch 411/1000
# No improvement. Patience: 72/300
# Epoch 412/1000
# No improvement. Patience: 73/300
# Epoch 413/1000
# No improvement. Patience: 74/300
# Epoch 414/1000
# No improvement. Patience: 75/300
# Epoch 415/1000
# No improvement. Patience: 76/300
# Epoch 416/1000
# No improvement. Patience: 77/300
# Epoch 417/1000
# No improvement. Patience: 78/300
# Epoch 418/1000
# No improvement. Patience: 79/300
# Epoch 419/1000
# No improvement. Patience: 80/300
# Epoch 420/1000
# No improvement. Patience: 81/300
# Epoch 421/1000
# No improvement. Patience: 82/300
# Epoch 422/1000
# No improvement. Patience: 83/300
# Epoch 423/1000
# No improvement. Patience: 84/300
# Epoch 424/1000
# No improvement. Patience: 85/300
# Epoch 425/1000
# No improvement. Patience: 86/300
# Epoch 426/1000
# No improvement. Patience: 87/300
# Epoch 427/1000
# No improvement. Patience: 88/300
# Epoch 428/1000
# No improvement. Patience: 89/300
# Epoch 429/1000
# No improvement. Patience: 90/300
# Epoch 430/1000
# No improvement. Patience: 91/300
# Epoch 431/1000
# No improvement. Patience: 92/300
# Epoch 432/1000
# No improvement. Patience: 93/300
# Epoch 433/1000
# No improvement. Patience: 94/300
# Epoch 434/1000
# No improvement. Patience: 95/300
# Epoch 435/1000
# No improvement. Patience: 96/300
# Epoch 436/1000
# No improvement. Patience: 97/300
# Epoch 437/1000
# No improvement. Patience: 98/300
# Epoch 438/1000
# No improvement. Patience: 99/300
# Epoch 439/1000
# No improvement. Patience: 100/300
# Epoch 440/1000
# No improvement. Patience: 101/300
# Epoch 441/1000
# No improvement. Patience: 102/300
# Epoch 442/1000
# No improvement. Patience: 103/300
# Epoch 443/1000
# No improvement. Patience: 104/300
# Epoch 444/1000
# No improvement. Patience: 105/300
# Epoch 445/1000
# No improvement. Patience: 106/300
# Epoch 446/1000
# No improvement. Patience: 107/300
# Epoch 447/1000
# No improvement. Patience: 108/300
# Epoch 448/1000
# No improvement. Patience: 109/300
# Epoch 449/1000
# No improvement. Patience: 110/300
# Epoch 450/1000
# No improvement. Patience: 111/300
# Epoch 451/1000
# No improvement. Patience: 112/300
# Epoch 452/1000
# No improvement. Patience: 113/300
# Epoch 453/1000
# No improvement. Patience: 114/300
# Epoch 454/1000
# No improvement. Patience: 115/300
# Epoch 455/1000
# No improvement. Patience: 116/300
# Epoch 456/1000
# No improvement. Patience: 117/300
# Epoch 457/1000
# No improvement. Patience: 118/300
# Epoch 458/1000
# No improvement. Patience: 119/300
# Epoch 459/1000
# Saved new best model at epoch 459 with Dice: 0.6297
# Epoch 460/1000
# No improvement. Patience: 1/300
# Epoch 461/1000
# No improvement. Patience: 2/300
# Epoch 462/1000
# No improvement. Patience: 3/300
# Epoch 463/1000
# No improvement. Patience: 4/300
# Epoch 464/1000
# No improvement. Patience: 5/300
# Epoch 465/1000
# No improvement. Patience: 6/300
# Epoch 466/1000
# No improvement. Patience: 7/300
# Epoch 467/1000
# No improvement. Patience: 8/300
# Epoch 468/1000
# No improvement. Patience: 9/300
# Epoch 469/1000
# No improvement. Patience: 10/300
# Epoch 470/1000
# No improvement. Patience: 11/300
# Epoch 471/1000
# No improvement. Patience: 12/300
# Epoch 472/1000
# No improvement. Patience: 13/300
# Epoch 473/1000
# No improvement. Patience: 14/300
# Epoch 474/1000
# No improvement. Patience: 15/300
# Epoch 475/1000
# No improvement. Patience: 16/300
# Epoch 476/1000
# No improvement. Patience: 17/300
# Epoch 477/1000
# No improvement. Patience: 18/300
# Epoch 478/1000
# No improvement. Patience: 19/300
# Epoch 479/1000
# No improvement. Patience: 20/300
# Epoch 480/1000
# No improvement. Patience: 21/300
# Epoch 481/1000
# No improvement. Patience: 22/300
# Epoch 482/1000
# No improvement. Patience: 23/300
# Epoch 483/1000
# No improvement. Patience: 24/300
# Epoch 484/1000
# No improvement. Patience: 25/300
# Epoch 485/1000
# No improvement. Patience: 26/300
# Epoch 486/1000
# No improvement. Patience: 27/300
# Epoch 487/1000
# No improvement. Patience: 28/300
# Epoch 488/1000
# No improvement. Patience: 29/300
# Epoch 489/1000
# No improvement. Patience: 30/300
# Epoch 490/1000
# No improvement. Patience: 31/300
# Epoch 491/1000
# No improvement. Patience: 32/300
# Epoch 492/1000
# No improvement. Patience: 33/300
# Epoch 493/1000
# No improvement. Patience: 34/300
# Epoch 494/1000
# No improvement. Patience: 35/300
# Epoch 495/1000
# No improvement. Patience: 36/300
# Epoch 496/1000
# No improvement. Patience: 37/300
# Epoch 497/1000
# No improvement. Patience: 38/300
# Epoch 498/1000
# No improvement. Patience: 39/300
# Epoch 499/1000
# No improvement. Patience: 40/300
# Epoch 500/1000
# No improvement. Patience: 41/300
# Epoch 501/1000
# No improvement. Patience: 42/300
# Epoch 502/1000
# No improvement. Patience: 43/300
# Epoch 503/1000
# No improvement. Patience: 44/300
# Epoch 504/1000
# No improvement. Patience: 45/300
# Epoch 505/1000
# No improvement. Patience: 46/300
# Epoch 506/1000
# No improvement. Patience: 47/300
# Epoch 507/1000
# No improvement. Patience: 48/300
# Epoch 508/1000
# No improvement. Patience: 49/300
# Epoch 509/1000
# No improvement. Patience: 50/300
# Epoch 510/1000
# No improvement. Patience: 51/300
# Epoch 511/1000
# No improvement. Patience: 52/300
# Epoch 512/1000
# No improvement. Patience: 53/300
# Epoch 513/1000
# No improvement. Patience: 54/300
# Epoch 514/1000
# No improvement. Patience: 55/300
# Epoch 515/1000
# No improvement. Patience: 56/300
# Epoch 516/1000
# No improvement. Patience: 57/300
# Epoch 517/1000
# No improvement. Patience: 58/300
# Epoch 518/1000
# No improvement. Patience: 59/300
# Epoch 519/1000
# No improvement. Patience: 60/300
# Epoch 520/1000
# No improvement. Patience: 61/300
# Epoch 521/1000
# No improvement. Patience: 62/300
# Epoch 522/1000
# No improvement. Patience: 63/300
# Epoch 523/1000
# No improvement. Patience: 64/300
# Epoch 524/1000
# No improvement. Patience: 65/300
# Epoch 525/1000
# No improvement. Patience: 66/300
# Epoch 526/1000
# No improvement. Patience: 67/300
# Epoch 527/1000
# No improvement. Patience: 68/300
# Epoch 528/1000
# No improvement. Patience: 69/300
# Epoch 529/1000
# No improvement. Patience: 70/300
# Epoch 530/1000
# No improvement. Patience: 71/300
# Epoch 531/1000
# No improvement. Patience: 72/300
# Epoch 532/1000
# No improvement. Patience: 73/300
# Epoch 533/1000
# No improvement. Patience: 74/300
# Epoch 534/1000
# No improvement. Patience: 75/300
# Epoch 535/1000
# No improvement. Patience: 76/300
# Epoch 536/1000
# No improvement. Patience: 77/300
# Epoch 537/1000
# No improvement. Patience: 78/300
# Epoch 538/1000
# No improvement. Patience: 79/300
# Epoch 539/1000
# No improvement. Patience: 80/300
# Epoch 540/1000
# No improvement. Patience: 81/300
# Epoch 541/1000
# No improvement. Patience: 82/300
# Epoch 542/1000
# No improvement. Patience: 83/300
# Epoch 543/1000
# No improvement. Patience: 84/300
# Epoch 544/1000
# No improvement. Patience: 85/300
# Epoch 545/1000
# No improvement. Patience: 86/300
# Epoch 546/1000
# No improvement. Patience: 87/300
# Epoch 547/1000
# No improvement. Patience: 88/300
# Epoch 548/1000
# No improvement. Patience: 89/300
# Epoch 549/1000
# No improvement. Patience: 90/300
# Epoch 550/1000
# No improvement. Patience: 91/300
# Epoch 551/1000
# No improvement. Patience: 92/300
# Epoch 552/1000
# No improvement. Patience: 93/300
# Epoch 553/1000
# No improvement. Patience: 94/300
# Epoch 554/1000
# No improvement. Patience: 95/300
# Epoch 555/1000
# No improvement. Patience: 96/300
# Epoch 556/1000
# No improvement. Patience: 97/300
# Epoch 557/1000
# No improvement. Patience: 98/300
# Epoch 558/1000
# No improvement. Patience: 99/300
# Epoch 559/1000
# No improvement. Patience: 100/300
# Epoch 560/1000
# No improvement. Patience: 101/300
# Epoch 561/1000
# No improvement. Patience: 102/300
# Epoch 562/1000
# No improvement. Patience: 103/300
# Epoch 563/1000
# No improvement. Patience: 104/300
# Epoch 564/1000
# No improvement. Patience: 105/300
# Epoch 565/1000
# No improvement. Patience: 106/300
# Epoch 566/1000
# No improvement. Patience: 107/300
# Epoch 567/1000
# No improvement. Patience: 108/300
# Epoch 568/1000
# No improvement. Patience: 109/300
# Epoch 569/1000
# No improvement. Patience: 110/300
# Epoch 570/1000
# No improvement. Patience: 111/300
# Epoch 571/1000
# No improvement. Patience: 112/300
# Epoch 572/1000
# No improvement. Patience: 113/300
# Epoch 573/1000
# No improvement. Patience: 114/300
# Epoch 574/1000
# No improvement. Patience: 115/300
# Epoch 575/1000
# No improvement. Patience: 116/300
# Epoch 576/1000
# No improvement. Patience: 117/300
# Epoch 577/1000
# No improvement. Patience: 118/300
# Epoch 578/1000
# No improvement. Patience: 119/300
# Epoch 579/1000
# No improvement. Patience: 120/300
# Epoch 580/1000
# No improvement. Patience: 121/300
# Epoch 581/1000
# No improvement. Patience: 122/300
# Epoch 582/1000
# No improvement. Patience: 123/300
# Epoch 583/1000
# No improvement. Patience: 124/300
# Epoch 584/1000
# No improvement. Patience: 125/300
# Epoch 585/1000
# No improvement. Patience: 126/300
# Epoch 586/1000
# No improvement. Patience: 127/300
# Epoch 587/1000
# No improvement. Patience: 128/300
# Epoch 588/1000
# No improvement. Patience: 129/300
# Epoch 589/1000
# No improvement. Patience: 130/300
# Epoch 590/1000
# No improvement. Patience: 131/300
# Epoch 591/1000
# No improvement. Patience: 132/300
# Epoch 592/1000
# No improvement. Patience: 133/300
# Epoch 593/1000
# No improvement. Patience: 134/300
# Epoch 594/1000
# No improvement. Patience: 135/300
# Epoch 595/1000
# No improvement. Patience: 136/300
# Epoch 596/1000
# No improvement. Patience: 137/300
# Epoch 597/1000
# No improvement. Patience: 138/300
# Epoch 598/1000
# No improvement. Patience: 139/300
# Epoch 599/1000
# No improvement. Patience: 140/300
# Epoch 600/1000
# No improvement. Patience: 141/300
# Epoch 601/1000
# No improvement. Patience: 142/300
# Epoch 602/1000
# Saved new best model at epoch 602 with Dice: 0.6317
# Epoch 603/1000
# No improvement. Patience: 1/300
# Epoch 604/1000
# Saved new best model at epoch 604 with Dice: 0.6377
# Epoch 605/1000
# No improvement. Patience: 1/300
# Epoch 606/1000
# No improvement. Patience: 2/300
# Epoch 607/1000
# No improvement. Patience: 3/300
# Epoch 608/1000
# No improvement. Patience: 4/300
# Epoch 609/1000
# No improvement. Patience: 5/300
# Epoch 610/1000
# No improvement. Patience: 6/300
# Epoch 611/1000
# No improvement. Patience: 7/300
# Epoch 612/1000
# No improvement. Patience: 8/300
# Epoch 613/1000
# No improvement. Patience: 9/300
# Epoch 614/1000
# No improvement. Patience: 10/300
# Epoch 615/1000
# No improvement. Patience: 11/300
# Epoch 616/1000
# No improvement. Patience: 12/300
# Epoch 617/1000
# No improvement. Patience: 13/300
# Epoch 618/1000
# No improvement. Patience: 14/300
# Epoch 619/1000
# No improvement. Patience: 15/300
# Epoch 620/1000
# No improvement. Patience: 16/300
# Epoch 621/1000
# No improvement. Patience: 17/300
# Epoch 622/1000
# No improvement. Patience: 18/300
# Epoch 623/1000
# No improvement. Patience: 19/300
# Epoch 624/1000
# No improvement. Patience: 20/300
# Epoch 625/1000
# No improvement. Patience: 21/300
# Epoch 626/1000
# No improvement. Patience: 22/300
# Epoch 627/1000
# No improvement. Patience: 23/300
# Epoch 628/1000
# No improvement. Patience: 24/300
# Epoch 629/1000
# No improvement. Patience: 25/300
# Epoch 630/1000
# No improvement. Patience: 26/300
# Epoch 631/1000
# No improvement. Patience: 27/300
# Epoch 632/1000
# No improvement. Patience: 28/300
# Epoch 633/1000
# No improvement. Patience: 29/300
# Epoch 634/1000
# No improvement. Patience: 30/300
# Epoch 635/1000
# No improvement. Patience: 31/300
# Epoch 636/1000
# No improvement. Patience: 32/300
# Epoch 637/1000
# No improvement. Patience: 33/300
# Epoch 638/1000
# No improvement. Patience: 34/300
# Epoch 639/1000
# No improvement. Patience: 35/300
# Epoch 640/1000
# No improvement. Patience: 36/300
# Epoch 641/1000
# No improvement. Patience: 37/300
# Epoch 642/1000
# No improvement. Patience: 38/300
# Epoch 643/1000
# No improvement. Patience: 39/300
# Epoch 644/1000
# No improvement. Patience: 40/300
# Epoch 645/1000
# No improvement. Patience: 41/300
# Epoch 646/1000
# No improvement. Patience: 42/300
# Epoch 647/1000
# No improvement. Patience: 43/300
# Epoch 648/1000
# No improvement. Patience: 44/300
# Epoch 649/1000
# No improvement. Patience: 45/300
# Epoch 650/1000
# No improvement. Patience: 46/300
# Epoch 651/1000
# No improvement. Patience: 47/300
# Epoch 652/1000
# No improvement. Patience: 48/300
# Epoch 653/1000
# No improvement. Patience: 49/300
# Epoch 654/1000
# No improvement. Patience: 50/300
# Epoch 655/1000
# No improvement. Patience: 51/300
# Epoch 656/1000
# No improvement. Patience: 52/300
# Epoch 657/1000
# No improvement. Patience: 53/300
# Epoch 658/1000
# No improvement. Patience: 54/300
# Epoch 659/1000
# No improvement. Patience: 55/300
# Epoch 660/1000
# No improvement. Patience: 56/300
# Epoch 661/1000
# No improvement. Patience: 57/300
# Epoch 662/1000
# No improvement. Patience: 58/300
# Epoch 663/1000
# No improvement. Patience: 59/300
# Epoch 664/1000
# No improvement. Patience: 60/300
# Epoch 665/1000
# No improvement. Patience: 61/300
# Epoch 666/1000
# No improvement. Patience: 62/300
# Epoch 667/1000
# No improvement. Patience: 63/300
# Epoch 668/1000
# No improvement. Patience: 64/300
# Epoch 669/1000
# No improvement. Patience: 65/300
# Epoch 670/1000
# No improvement. Patience: 66/300
# Epoch 671/1000
# No improvement. Patience: 67/300
# Epoch 672/1000
# No improvement. Patience: 68/300
# Epoch 673/1000
# No improvement. Patience: 69/300
# Epoch 674/1000
# No improvement. Patience: 70/300
# Epoch 675/1000
# No improvement. Patience: 71/300
# Epoch 676/1000
# No improvement. Patience: 72/300
# Epoch 677/1000
# No improvement. Patience: 73/300
# Epoch 678/1000
# No improvement. Patience: 74/300
# Epoch 679/1000
# No improvement. Patience: 75/300
# Epoch 680/1000
# No improvement. Patience: 76/300
# Epoch 681/1000
# No improvement. Patience: 77/300
# Epoch 682/1000
# No improvement. Patience: 78/300
# Epoch 683/1000
# No improvement. Patience: 79/300
# Epoch 684/1000
# No improvement. Patience: 80/300
# Epoch 685/1000
# No improvement. Patience: 81/300
# Epoch 686/1000
# No improvement. Patience: 82/300
# Epoch 687/1000
# No improvement. Patience: 83/300
# Epoch 688/1000
# No improvement. Patience: 84/300
# Epoch 689/1000
# No improvement. Patience: 85/300
# Epoch 690/1000
# No improvement. Patience: 86/300
# Epoch 691/1000
# No improvement. Patience: 87/300
# Epoch 692/1000
# No improvement. Patience: 88/300
# Epoch 693/1000
# No improvement. Patience: 89/300
# Epoch 694/1000
# No improvement. Patience: 90/300
# Epoch 695/1000
# No improvement. Patience: 91/300
# Epoch 696/1000
# No improvement. Patience: 92/300
# Epoch 697/1000
# No improvement. Patience: 93/300
# Epoch 698/1000
# No improvement. Patience: 94/300
# Epoch 699/1000
# No improvement. Patience: 95/300
# Epoch 700/1000
# No improvement. Patience: 96/300
# Epoch 701/1000
# No improvement. Patience: 97/300
# Epoch 702/1000
# No improvement. Patience: 98/300
# Epoch 703/1000
# No improvement. Patience: 99/300
# Epoch 704/1000
# No improvement. Patience: 100/300
# Epoch 705/1000
# No improvement. Patience: 101/300
# Epoch 706/1000
# No improvement. Patience: 102/300
# Epoch 707/1000
# No improvement. Patience: 103/300
# Epoch 708/1000
# No improvement. Patience: 104/300
# Epoch 709/1000
# No improvement. Patience: 105/300
# Epoch 710/1000
# No improvement. Patience: 106/300
# Epoch 711/1000
# No improvement. Patience: 107/300
# Epoch 712/1000
# No improvement. Patience: 108/300
# Epoch 713/1000
# No improvement. Patience: 109/300
# Epoch 714/1000
# No improvement. Patience: 110/300
# Epoch 715/1000
# No improvement. Patience: 111/300
# Epoch 716/1000
# Saved new best model at epoch 716 with Dice: 0.6465
# Epoch 717/1000
# No improvement. Patience: 1/300
# Epoch 718/1000
# No improvement. Patience: 2/300
# Epoch 719/1000
# No improvement. Patience: 3/300
# Epoch 720/1000
# No improvement. Patience: 4/300
# Epoch 721/1000
# No improvement. Patience: 5/300
# Epoch 722/1000
# No improvement. Patience: 6/300
# Epoch 723/1000
# No improvement. Patience: 7/300
# Epoch 724/1000
# No improvement. Patience: 8/300
# Epoch 725/1000
# No improvement. Patience: 9/300
# Epoch 726/1000
# No improvement. Patience: 10/300
# Epoch 727/1000
# No improvement. Patience: 11/300
# Epoch 728/1000
# No improvement. Patience: 12/300
# Epoch 729/1000
# No improvement. Patience: 13/300
# Epoch 730/1000
# No improvement. Patience: 14/300
# Epoch 731/1000
# No improvement. Patience: 15/300
# Epoch 732/1000
# No improvement. Patience: 16/300
# Epoch 733/1000
# No improvement. Patience: 17/300
# Epoch 734/1000
# No improvement. Patience: 18/300
# Epoch 735/1000
# No improvement. Patience: 19/300
# Epoch 736/1000
# No improvement. Patience: 20/300
# Epoch 737/1000
# No improvement. Patience: 21/300
# Epoch 738/1000
# No improvement. Patience: 22/300
# Epoch 739/1000
# No improvement. Patience: 23/300
# Epoch 740/1000
# No improvement. Patience: 24/300
# Epoch 741/1000
# No improvement. Patience: 25/300
# Epoch 742/1000
# No improvement. Patience: 26/300
# Epoch 743/1000
# No improvement. Patience: 27/300
# Epoch 744/1000
# No improvement. Patience: 28/300
# Epoch 745/1000
# No improvement. Patience: 29/300
# Epoch 746/1000
# No improvement. Patience: 30/300
# Epoch 747/1000
# No improvement. Patience: 31/300
# Epoch 748/1000
# No improvement. Patience: 32/300
# Epoch 749/1000
# No improvement. Patience: 33/300
# Epoch 750/1000
# No improvement. Patience: 34/300
# Epoch 751/1000
# No improvement. Patience: 35/300
# Epoch 752/1000
# No improvement. Patience: 36/300
# Epoch 753/1000
# No improvement. Patience: 37/300
# Epoch 754/1000
# No improvement. Patience: 38/300
# Epoch 755/1000
# No improvement. Patience: 39/300
# Epoch 756/1000
# No improvement. Patience: 40/300
# Epoch 757/1000
# No improvement. Patience: 41/300
# Epoch 758/1000
# No improvement. Patience: 42/300
# Epoch 759/1000
# No improvement. Patience: 43/300
# Epoch 760/1000
# No improvement. Patience: 44/300
# Epoch 761/1000
# No improvement. Patience: 45/300
# Epoch 762/1000
# No improvement. Patience: 46/300
# Epoch 763/1000
# No improvement. Patience: 47/300
# Epoch 764/1000
# No improvement. Patience: 48/300
# Epoch 765/1000
# No improvement. Patience: 49/300
# Epoch 766/1000
# No improvement. Patience: 50/300
# Epoch 767/1000
# No improvement. Patience: 51/300
# Epoch 768/1000
# No improvement. Patience: 52/300
# Epoch 769/1000
# No improvement. Patience: 53/300
# Epoch 770/1000
# No improvement. Patience: 54/300
# Epoch 771/1000
# No improvement. Patience: 55/300
# Epoch 772/1000
# No improvement. Patience: 56/300
# Epoch 773/1000
# No improvement. Patience: 57/300
# Epoch 774/1000
# No improvement. Patience: 58/300
# Epoch 775/1000
# No improvement. Patience: 59/300
# Epoch 776/1000
# No improvement. Patience: 60/300
# Epoch 777/1000
# No improvement. Patience: 61/300
# Epoch 778/1000
# No improvement. Patience: 62/300
# Epoch 779/1000
# No improvement. Patience: 63/300
# Epoch 780/1000
# No improvement. Patience: 64/300
# Epoch 781/1000
# No improvement. Patience: 65/300
# Epoch 782/1000
# No improvement. Patience: 66/300
# Epoch 783/1000
# No improvement. Patience: 67/300
# Epoch 784/1000
# No improvement. Patience: 68/300
# Epoch 785/1000
# No improvement. Patience: 69/300
# Epoch 786/1000
# No improvement. Patience: 70/300
# Epoch 787/1000
# No improvement. Patience: 71/300
# Epoch 788/1000
# No improvement. Patience: 72/300
# Epoch 789/1000
# No improvement. Patience: 73/300
# Epoch 790/1000
# No improvement. Patience: 74/300
# Epoch 791/1000
# No improvement. Patience: 75/300
# Epoch 792/1000
# No improvement. Patience: 76/300
# Epoch 793/1000
# No improvement. Patience: 77/300
# Epoch 794/1000
# No improvement. Patience: 78/300
# Epoch 795/1000
# No improvement. Patience: 79/300
# Epoch 796/1000
# No improvement. Patience: 80/300
# Epoch 797/1000
# No improvement. Patience: 81/300
# Epoch 798/1000
# No improvement. Patience: 82/300
# Epoch 799/1000
# No improvement. Patience: 83/300
# Epoch 800/1000
# No improvement. Patience: 84/300
# Epoch 801/1000
# No improvement. Patience: 85/300
# Epoch 802/1000
# No improvement. Patience: 86/300
# Epoch 803/1000
# No improvement. Patience: 87/300
# Epoch 804/1000
# No improvement. Patience: 88/300
# Epoch 805/1000
# No improvement. Patience: 89/300
# Epoch 806/1000
# No improvement. Patience: 90/300
# Epoch 807/1000
# No improvement. Patience: 91/300
# Epoch 808/1000
# No improvement. Patience: 92/300
# Epoch 809/1000
# No improvement. Patience: 93/300
# Epoch 810/1000
# No improvement. Patience: 94/300
# Epoch 811/1000
# No improvement. Patience: 95/300
# Epoch 812/1000
# No improvement. Patience: 96/300
# Epoch 813/1000
# No improvement. Patience: 97/300
# Epoch 814/1000
# No improvement. Patience: 98/300
# Epoch 815/1000
# No improvement. Patience: 99/300
# Epoch 816/1000
# No improvement. Patience: 100/300
# Epoch 817/1000
# No improvement. Patience: 101/300
# Epoch 818/1000
# No improvement. Patience: 102/300
# Epoch 819/1000
# No improvement. Patience: 103/300
# Epoch 820/1000
# No improvement. Patience: 104/300
# Epoch 821/1000
# No improvement. Patience: 105/300
# Epoch 822/1000
# No improvement. Patience: 106/300
# Epoch 823/1000
# No improvement. Patience: 107/300
# Epoch 824/1000
# No improvement. Patience: 108/300
# Epoch 825/1000
# No improvement. Patience: 109/300
# Epoch 826/1000
# No improvement. Patience: 110/300
# Epoch 827/1000
# No improvement. Patience: 111/300
# Epoch 828/1000
# No improvement. Patience: 112/300
# Epoch 829/1000
# No improvement. Patience: 113/300
# Epoch 830/1000
# No improvement. Patience: 114/300
# Epoch 831/1000
# No improvement. Patience: 115/300
# Epoch 832/1000
# No improvement. Patience: 116/300
# Epoch 833/1000
# No improvement. Patience: 117/300
# Epoch 834/1000
# No improvement. Patience: 118/300
# Epoch 835/1000
# No improvement. Patience: 119/300
# Epoch 836/1000
# No improvement. Patience: 120/300
# Epoch 837/1000
# No improvement. Patience: 121/300
# Epoch 838/1000
# No improvement. Patience: 122/300
# Epoch 839/1000
# No improvement. Patience: 123/300
# Epoch 840/1000
# No improvement. Patience: 124/300
# Epoch 841/1000
# No improvement. Patience: 125/300
# Epoch 842/1000
# No improvement. Patience: 126/300
# Epoch 843/1000
# No improvement. Patience: 127/300
# Epoch 844/1000
# No improvement. Patience: 128/300
# Epoch 845/1000
# No improvement. Patience: 129/300
# Epoch 846/1000
# No improvement. Patience: 130/300
# Epoch 847/1000
# No improvement. Patience: 131/300
# Epoch 848/1000
# No improvement. Patience: 132/300
# Epoch 849/1000
# No improvement. Patience: 133/300
# Epoch 850/1000
# No improvement. Patience: 134/300
# Epoch 851/1000
# No improvement. Patience: 135/300
# Epoch 852/1000
# No improvement. Patience: 136/300
# Epoch 853/1000
# No improvement. Patience: 137/300
# Epoch 854/1000
# No improvement. Patience: 138/300
# Epoch 855/1000
# No improvement. Patience: 139/300
# Epoch 856/1000
# No improvement. Patience: 140/300
# Epoch 857/1000
# No improvement. Patience: 141/300
# Epoch 858/1000
# No improvement. Patience: 142/300
# Epoch 859/1000
# No improvement. Patience: 143/300
# Epoch 860/1000
# No improvement. Patience: 144/300
# Epoch 861/1000
# No improvement. Patience: 145/300
# Epoch 862/1000
# No improvement. Patience: 146/300
# Epoch 863/1000
# No improvement. Patience: 147/300
# Epoch 864/1000
# No improvement. Patience: 148/300
# Epoch 865/1000
# No improvement. Patience: 149/300
# Epoch 866/1000
# No improvement. Patience: 150/300
# Epoch 867/1000
# No improvement. Patience: 151/300
# Epoch 868/1000
# No improvement. Patience: 152/300
# Epoch 869/1000
# No improvement. Patience: 153/300
# Epoch 870/1000
# No improvement. Patience: 154/300
# Epoch 871/1000
# No improvement. Patience: 155/300
# Epoch 872/1000
# No improvement. Patience: 156/300
# Epoch 873/1000
# No improvement. Patience: 157/300
# Epoch 874/1000
# No improvement. Patience: 158/300
# Epoch 875/1000
# No improvement. Patience: 159/300
# Epoch 876/1000
# No improvement. Patience: 160/300
# Epoch 877/1000
# No improvement. Patience: 161/300
# Epoch 878/1000
# No improvement. Patience: 162/300
# Epoch 879/1000
# No improvement. Patience: 163/300
# Epoch 880/1000
# No improvement. Patience: 164/300
# Epoch 881/1000
# No improvement. Patience: 165/300
# Epoch 882/1000
# No improvement. Patience: 166/300
# Epoch 883/1000
# No improvement. Patience: 167/300
# Epoch 884/1000
# No improvement. Patience: 168/300
# Epoch 885/1000
# No improvement. Patience: 169/300
# Epoch 886/1000
# No improvement. Patience: 170/300
# Epoch 887/1000
# No improvement. Patience: 171/300
# Epoch 888/1000
# No improvement. Patience: 172/300
# Epoch 889/1000
# No improvement. Patience: 173/300
# Epoch 890/1000
# No improvement. Patience: 174/300
# Epoch 891/1000
# No improvement. Patience: 175/300
# Epoch 892/1000
# No improvement. Patience: 176/300
# Epoch 893/1000
# No improvement. Patience: 177/300
# Epoch 894/1000
# No improvement. Patience: 178/300
# Epoch 895/1000
# No improvement. Patience: 179/300
# Epoch 896/1000
# No improvement. Patience: 180/300
# Epoch 897/1000
# No improvement. Patience: 181/300
# Epoch 898/1000
# No improvement. Patience: 182/300
# Epoch 899/1000
# No improvement. Patience: 183/300
# Epoch 900/1000
# No improvement. Patience: 184/300
# Epoch 901/1000
# No improvement. Patience: 185/300
# Epoch 902/1000
# No improvement. Patience: 186/300
# Epoch 903/1000
# No improvement. Patience: 187/300
# Epoch 904/1000
# No improvement. Patience: 188/300
# Epoch 905/1000
# No improvement. Patience: 189/300
# Epoch 906/1000
# No improvement. Patience: 190/300
# Epoch 907/1000
# No improvement. Patience: 191/300
# Epoch 908/1000
# No improvement. Patience: 192/300
# Epoch 909/1000
# No improvement. Patience: 193/300
# Epoch 910/1000
# No improvement. Patience: 194/300
# Epoch 911/1000
# No improvement. Patience: 195/300
# Epoch 912/1000
# No improvement. Patience: 196/300
# Epoch 913/1000
# No improvement. Patience: 197/300
# Epoch 914/1000
# No improvement. Patience: 198/300
# Epoch 915/1000
# No improvement. Patience: 199/300
# Epoch 916/1000
# No improvement. Patience: 200/300
# Epoch 917/1000
# No improvement. Patience: 201/300
# Epoch 918/1000
# No improvement. Patience: 202/300
# Epoch 919/1000
# No improvement. Patience: 203/300
# Epoch 920/1000
# No improvement. Patience: 204/300
# Epoch 921/1000
# No improvement. Patience: 205/300
# Epoch 922/1000
# No improvement. Patience: 206/300
# Epoch 923/1000
# No improvement. Patience: 207/300
# Epoch 924/1000
# No improvement. Patience: 208/300
# Epoch 925/1000
# No improvement. Patience: 209/300
# Epoch 926/1000
# No improvement. Patience: 210/300
# Epoch 927/1000
# No improvement. Patience: 211/300
# Epoch 928/1000
# No improvement. Patience: 212/300
# Epoch 929/1000
# No improvement. Patience: 213/300
# Epoch 930/1000
# No improvement. Patience: 214/300
# Epoch 931/1000
# No improvement. Patience: 215/300
# Epoch 932/1000
# No improvement. Patience: 216/300
# Epoch 933/1000
# No improvement. Patience: 217/300
# Epoch 934/1000
# No improvement. Patience: 218/300
# Epoch 935/1000
# No improvement. Patience: 219/300
# Epoch 936/1000
# No improvement. Patience: 220/300
# Epoch 937/1000
# No improvement. Patience: 221/300
# Epoch 938/1000
# No improvement. Patience: 222/300
# Epoch 939/1000
# No improvement. Patience: 223/300
# Epoch 940/1000
# No improvement. Patience: 224/300
# Epoch 941/1000
# No improvement. Patience: 225/300
# Epoch 942/1000
# No improvement. Patience: 226/300
# Epoch 943/1000
# No improvement. Patience: 227/300
# Epoch 944/1000
# No improvement. Patience: 228/300
# Epoch 945/1000
# No improvement. Patience: 229/300
# Epoch 946/1000
# No improvement. Patience: 230/300
# Epoch 947/1000
# No improvement. Patience: 231/300
# Epoch 948/1000
# No improvement. Patience: 232/300
# Epoch 949/1000
# No improvement. Patience: 233/300
# Epoch 950/1000
# No improvement. Patience: 234/300
# Epoch 951/1000
# No improvement. Patience: 235/300
# Epoch 952/1000
# No improvement. Patience: 236/300
# Epoch 953/1000
# No improvement. Patience: 237/300
# Epoch 954/1000
# No improvement. Patience: 238/300
# Epoch 955/1000
# No improvement. Patience: 239/300
# Epoch 956/1000
# No improvement. Patience: 240/300
# Epoch 957/1000
# No improvement. Patience: 241/300
# Epoch 958/1000
# No improvement. Patience: 242/300
# Epoch 959/1000
# No improvement. Patience: 243/300
# Epoch 960/1000
# No improvement. Patience: 244/300
# Epoch 961/1000
# No improvement. Patience: 245/300
# Epoch 962/1000
# No improvement. Patience: 246/300
# Epoch 963/1000
# No improvement. Patience: 247/300
# Epoch 964/1000
# No improvement. Patience: 248/300
# Epoch 965/1000
# No improvement. Patience: 249/300
# Epoch 966/1000
# No improvement. Patience: 250/300
# Epoch 967/1000
# No improvement. Patience: 251/300
# Epoch 968/1000
# No improvement. Patience: 252/300
# Epoch 969/1000
# No improvement. Patience: 253/300
# Epoch 970/1000
# No improvement. Patience: 254/300
# Epoch 971/1000
# No improvement. Patience: 255/300
# Epoch 972/1000
# No improvement. Patience: 256/300
# Epoch 973/1000
# No improvement. Patience: 257/300
# Epoch 974/1000
# No improvement. Patience: 258/300
# Epoch 975/1000
# No improvement. Patience: 259/300
# Epoch 976/1000
# No improvement. Patience: 260/300
# Epoch 977/1000
# No improvement. Patience: 261/300
# Epoch 978/1000
# No improvement. Patience: 262/300
# Epoch 979/1000
# No improvement. Patience: 263/300
# Epoch 980/1000
