# %%
# Uncomment to install `sklearn-pandas`
! pip install sklearn-pandas
# Out:
# Collecting sklearn-pandas
#   Downloading sklearn_pandas-2.2.0-py2.py3-none-any.whl.metadata (445 bytes)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from sklearn-pandas) (1.6.0)
# Requirement already satisfied: scipy>=1.5.1 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from sklearn-pandas) (1.13.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from sklearn-pandas) (2.2.3)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from sklearn-pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from pandas>=1.1.4->sklearn-pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from pandas>=1.1.4->sklearn-pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from pandas>=1.1.4->sklearn-pandas) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from scikit-learn>=0.23.0->sklearn-pandas) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from scikit-learn>=0.23.0->sklearn-pandas) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\datn\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.4->sklearn-pandas) (1.17.0)
# Downloading sklearn_pandas-2.2.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sklearn-pandas
# Successfully installed sklearn-pandas-2.2.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper

import torch
import torchtuples as tt

from pycox.datasets import metabric
from pycox.models import CoxPH
from pycox.evaluation import EvalSurv

# %%
np.random.seed(1234)
_ = torch.manual_seed(123)

# %%
df_train = pd.read_csv("E:/DATN_LVTN/SA/without_image/Pycox/processed_data.csv")
df_test = df_train.sample(frac=0.2)
df_train = df_train.drop(df_test.index)
df_val = df_train.sample(frac=0.2)
df_train = df_train.drop(df_val.index)
df_train.head()
# Out:
#    Age  Weight (lbs)  Gender  Ethnicity  Smoking status  %GG  \
# 1   65         195.0       0          1               2    0
# 2   65         173.5       1          2               0    0
# 3   67         173.5       1          2               1    0
# 4   84         145.0       1          4               1    0
# 5   62         173.5       1          2               1    0
#
#    Tumor Location (choice=RUL)  Tumor Location (choice=RML)  \
# 1                            0                            1
# 2                            1                            1
# 3                            1                            1
# 4                            1                            0
# 5                            1                            1
#
#    Tumor Location (choice=RLL)  Tumor Location (choice=LUL)  ...  \
# 1                            1                            1  ...
# 2                            1                            1  ...
# 3                            1                            0  ...
# 4                            1                            1  ...
# 5                            1                            0  ...
#
#    EGFR mutation status  KRAS mutation status  ALK translocation status  \
# 1                     1                     1                         1
# 2                     0                     0                         2
# 3                     2                     2                         2
# 4                     2                     1                         2
# 5                     2                     2                         2
#
#    Adjuvant Treatment  Chemotherapy  Radiation  Recurrence  Survival Status  \
# 1                   0             0          0           0                0
# 2                   0             0          0           0                0
# 3                   1             1          1           1                0
# 4                   0             0          0           1                1
# 5                   0             0          0           0                0
#
#    Time to Event  Days between CT and surgery
# 1             70                           23
# 2            666                           25
# 3           1172                           89
# 4           1456                           92
# 5           2297                          315
#
# [5 rows x 28 columns]

# %%
cols_standardize = ['Age', 'Weight (lbs)', 'Ethnicity', 'Smoking status', '%GG', 'Histology', 'Pathological T stage', 'Pathological N stage', 'Pathological M stage', 
                    'Histopathological Grade', 'Lymphovascular invasion', 'EGFR mutation status', 'KRAS mutation status', 'ALK translocation status', 'Days between CT and surgery']
cols_leave = ['Tumor Location (choice=RUL)', 'Tumor Location (choice=RML)', 'Tumor Location (choice=RLL)', 'Tumor Location (choice=LUL)', 'Tumor Location (choice=LLL)',
              'Pleural invasion (elastic, visceral, or parietal)', 'Adjuvant Treatment', 'Chemotherapy', 'Radiation', 'Recurrence']

standardize = [([col], StandardScaler()) for col in cols_standardize]
leave = [(col, None) for col in cols_leave]

x_mapper = DataFrameMapper(standardize + leave)

# %%
x_train = x_mapper.fit_transform(df_train).astype('float32')
x_val = x_mapper.transform(df_val).astype('float32')
x_test = x_mapper.transform(df_test).astype('float32')

# %%
get_target = lambda df: (df['Time to Event'].values, df['Survival Status'].values)
y_train = get_target(df_train)
y_val = get_target(df_val)
durations_test, events_test = get_target(df_test)
val = x_val, y_val

# %%
in_features = x_train.shape[1]
num_nodes = [32, 32]
out_features = 1
batch_norm = True
dropout = 0.1
output_bias = False

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm,
                              dropout, output_bias=output_bias)

# %%
model = CoxPH(net, tt.optim.Adam)

# %%
batch_size = 32
lrfinder = model.lr_finder(x_train, y_train, batch_size, tolerance=10)
_ = lrfinder.plot()
# Out:
# c:\Users\ADMIN\anaconda3\envs\DATN\lib\site-packages\torchtuples\base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
lrfinder.get_best_lr()
# Out:
# 0.02420128264794396

# %%
model.optimizer.set_lr(0.01)

# %%
epochs = 500
callbacks = [tt.callbacks.EarlyStopping()]
verbose = True

# %%
# %%time
log = model.fit(x_train, y_train, batch_size, epochs, callbacks, verbose,
                val_data=val, val_batch_size=batch_size)
# Out:
# 0:	[0s / 0s],		train_loss: 3.0136,	val_loss: 2.9534
# 1:	[0s / 0s],		train_loss: 2.7663,	val_loss: 2.8268
# 2:	[0s / 0s],		train_loss: 2.7098,	val_loss: 2.7381
# 3:	[0s / 0s],		train_loss: 2.4119,	val_loss: 2.6638
# 4:	[0s / 0s],		train_loss: 2.3295,	val_loss: 2.6468
# 5:	[0s / 0s],		train_loss: 2.3312,	val_loss: 2.6699
# 6:	[0s / 0s],		train_loss: 2.1495,	val_loss: 2.7283
# 7:	[0s / 0s],		train_loss: 2.0050,	val_loss: 2.8073
# 8:	[0s / 0s],		train_loss: 1.8601,	val_loss: 2.9488
# 9:	[0s / 0s],		train_loss: 1.9205,	val_loss: 3.0809
# 10:	[0s / 0s],		train_loss: 1.5941,	val_loss: 3.2853
# 11:	[0s / 0s],		train_loss: 1.6736,	val_loss: 3.6262
# 12:	[0s / 0s],		train_loss: 1.5266,	val_loss: 3.9289
# 13:	[0s / 0s],		train_loss: 1.6150,	val_loss: 4.1598
# 14:	[0s / 0s],		train_loss: 1.5976,	val_loss: 4.4299
# CPU times: total: 0 ns
# Wall time: 191 ms
# c:\Users\ADMIN\anaconda3\envs\DATN\lib\site-packages\torchtuples\base.py:669: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.net.load_state_dict(torch.load(path, **kwargs))

# %%
_ = log.plot()

# %%
model.partial_log_likelihood(*val).mean()
# Out:
# -2.6467698

# %%
_ = model.compute_baseline_hazards()
surv = model.predict_surv_df(x_test)

# %%
surv.iloc[:, :5].plot()
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
ev = EvalSurv(surv, durations_test, events_test, censor_surv='km')
ev.concordance_td()
# Out:
# 0.6131386861313869
